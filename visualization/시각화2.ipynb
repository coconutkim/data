# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.linspace(0,10,100)
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
x = np.linspace(-10,10,100)

# %%
y = 2*x

# %%
y
# Out:
# array([-20.        , -19.5959596 , -19.19191919, -18.78787879,
#        -18.38383838, -17.97979798, -17.57575758, -17.17171717,
#        -16.76767677, -16.36363636, -15.95959596, -15.55555556,
#        -15.15151515, -14.74747475, -14.34343434, -13.93939394,
#        -13.53535354, -13.13131313, -12.72727273, -12.32323232,
#        -11.91919192, -11.51515152, -11.11111111, -10.70707071,
#        -10.3030303 ,  -9.8989899 ,  -9.49494949,  -9.09090909,
#         -8.68686869,  -8.28282828,  -7.87878788,  -7.47474747,
#         -7.07070707,  -6.66666667,  -6.26262626,  -5.85858586,
#         -5.45454545,  -5.05050505,  -4.64646465,  -4.24242424,
#         -3.83838384,  -3.43434343,  -3.03030303,  -2.62626263,
#         -2.22222222,  -1.81818182,  -1.41414141,  -1.01010101,
#         -0.60606061,  -0.2020202 ,   0.2020202 ,   0.60606061,
#          1.01010101,   1.41414141,   1.81818182,   2.22222222,
#          2.62626263,   3.03030303,   3.43434343,   3.83838384,
# ...

# %%
plt.plot(x,y)

# %% [markdown]
# ### [<matplotlib.lines.Line2D at 0x23445b73350>]의 의미
#
# Matplotlib에서 플롯(예: 선 그래프)을 그릴 때, 그래프를 시각적으로 표시하지 않고, 단순히 해당 객체를 출력할 때 나타나는 Python 객체의 표현입니다

# %%
plt.figure(figsize=(5,5))
# 단위는 인치
plt.plot(x,y)
plt.show()

# %%
plt.figure(figsize=(8,4))
# 단위는 인치
plt.plot(x,y,'--g')
# 선 모양 색깔 순
plt.show()

# %%
y = x**2

# %%
plt.figure(figsize=(8,4))
# 단위는 인치
plt.plot(x,y,'--g')
# 선 모양 색깔 순
plt.show()

# %% [markdown]
# # 정규분포 그래프 그리기

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = np.linspace(-5,5,100)

# %%
sigma = 1.0
mean = 0.0

# %%
np.pi
# Out:
# 3.141592653589793

# %%
y = (1.0/(np.sqrt(2.0*np.pi*sigma)))*np.exp(1.0)**-((x-mean)**2.0/(2.0*sigma**2.0))

# %%
sigma2 = 2.0

# %%
y2 = (1.0/(np.sqrt(2.0*np.pi*sigma2)))*np.exp(1.0)**-((x-mean)**2.0/(2.0*sigma2**2.0))

# %%
sigma3 = 3.0

# %%
y3 = (1.0/(np.sqrt(2.0*np.pi*sigma3)))*np.exp(1.0)**-((x-mean)**2.0/(2.0*sigma3**2.0))

# %%
plt.plot(x,y,x,y2,x,y3)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.show()

# %%
np.array(['1사분기','1사분기','1사분기','1사분기'])
# Out:
# array(['1사분기', '1사분기', '1사분기', '1사분기'], dtype='<U4')

# %%
x = np.array(['1분기','2분기','3분기','4분기'])

# %%
np.array
# Out:
# <function numpy.array>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
y = np.array([234,	254.7,	144.6,	317.6])

# %%
from matplotlib import font_manager,rc

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
# 설치된 폰트 목록 확인
plt.rcParams['axes.unicode_minus'] = False

# %%
plt.bar(x,y)
plt.show()

# %%
import numpy as np

# %%
x = np.linspace(0,10,100)
y = np.sin(x)
z = np.cos(x)

# %%
import matplotlib.pyplot as plt

# %%
fig0 = plt.figure()

# %%
help(fig0.add_axes)

# %%
axes0 = fig0.add_axes([0,0,1,1])

# %%
x = np.linspace(0,10,100)
y = np.sin(x)
z = np.cos(x)
fig0 = plt.figure()
axes0 = fig0.add_axes([0,0,1,1])
axes0.plot(x,y)
plt.show()

# %%
x = np.linspace(0,10,100)
y = np.sin(x)
z = np.cos(x)
fig0 = plt.figure()
axes0 = fig0.add_axes([0,0,1,2])
axes0.plot(x,y)
plt.show()
