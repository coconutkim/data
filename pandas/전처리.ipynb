# %% [markdown]
# # 데이터 전처리

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 변수를 가지고 파생시켜 새로운 변수를 만들어낸다
#
# > EDA
#
# -단순 시각화 > 분석의 방향 설정

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# > 아웃라이어 찾는 방법
#
# 박스플롯을 이용한다
#
# 25퍼센트,75퍼센트에 중점을 둔다
#
# 주로 3분위수 벗어나는 것들을 관찰한다

# %% [markdown]
# > 앙상블 기법(쉽게 말해 짬뽕한다)
#
# voting: 투표하는 방식
#
# bagging: bootstrap aggregation의 약자
#
# boosting: 잘못된 것을 계속 업데이트해서 발전해나간다

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 표 안에 들어간 것들 >  정형 데이터

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
