# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('C:/ex/data/경기도 고양시_주정차위반단속위치현황_20240604.csv',encoding='cp949')
# Out:
#         집계년도  시군명   시군코드      관리기관명             단속일시정보                   단속장소  \
# 0       2022  고양시  41280   고양시 덕양구청   2022-02-23 15:15                    향동로
# 1       2022  고양시  41280   고양시 덕양구청   2022-02-18 15:25                    향동로
# 2       2022  고양시  41280   고양시 덕양구청   2022-02-18 15:27                    향동로
# 3       2022  고양시  41280   고양시 덕양구청   2022-02-23 15:12                    향동로
# 4       2022  고양시  41280   고양시 덕양구청   2022-02-23 15:14                    향동로
# ...      ...  ...    ...        ...                ...                    ...
# 234744  2022  고양시  41280  고양시 일산서구청   2022-12-31 17:19  SP-7518 우리은행 일산중앙지점 앞
# 234745  2022  고양시  41280  고양시 일산서구청   2022-12-31 17:23           2033번지 소화전주변
# 234746  2022  고양시  41280  고양시 일산서구청   2022-12-31 17:39    P-7527 주엽119안전센터 후문
# 234747  2022  고양시  41280  고양시 일산서구청   2022-12-31 17:44    P-7527 주엽119안전센터 후문
# 234748  2022  고양시  41280  고양시 일산서구청   2022-12-31 23:06           1876번지 모퉁이주변
#
#            단속방법     데이터기준일자
# 0           PDA  2024-06-04
# 1           PDA  2024-06-04
# 2           PDA  2024-06-04
# 3           PDA  2024-06-04
# 4           PDA  2024-06-04
# ...         ...         ...
# 234744  고정형CCTV  2024-06-04
# 234745    시민신고웹  2024-06-04
# 234746  고정형CCTV  2024-06-04
# 234747  고정형CCTV  2024-06-04
# 234748    시민신고웹  2024-06-04
#
# [234749 rows x 8 columns]

# %%
badcar = pd.read_csv('C:/ex/data/경기도 고양시_주정차위반단속위치현황_20240604.csv',encoding='cp949')

# %%
badcar['관리기관명'].unique()
# Out:
# array(['고양시 덕양구청', '고양시 일산동구청', '고양시 일산서구청'], dtype=object)

# %%
badcar['관리기관명'].value_counts()
# 덕양구 165.5 km²
# 일산동구 	59.1km2
# 일산서구 42.6 km2
# Out:
# 관리기관명
# 고양시 덕양구청     100636
# 고양시 일산동구청     76811
# 고양시 일산서구청     57302
# Name: count, dtype: int64

# %%
# 면적/단속현황 수
print(165.5/100636)
print(59.1/76811)
print(42.6/57302)
# Out:
# 0.0016445407210143488
# 0.0007694210464646991
# 0.0007434295487068514

# %%
# 24시간을 3시간씩 구간으로 나누어본다
badcar['단속일시정보'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0          2022-02-23 15:15
# 1          2022-02-18 15:25
# 2          2022-02-18 15:27
# 3          2022-02-23 15:12
# 4          2022-02-23 15:14
#                 ...
# 234744     2022-12-31 17:19
# 234745     2022-12-31 17:23
# 234746     2022-12-31 17:39
# 234747     2022-12-31 17:44
# 234748     2022-12-31 23:06
# Name: 단속일시정보, Length: 234749, dtype: object>

# %%
timevalue = badcar['단속일시정보'].values
timevalue
# Out:
# array([' 2022-02-23 15:15', ' 2022-02-18 15:25', ' 2022-02-18 15:27', ...,
#        ' 2022-12-31 17:39', ' 2022-12-31 17:44', ' 2022-12-31 23:06'],
#       dtype=object)

# %%
badcar['단속일시정보'] = pd.to_datetime(badcar['단속일시정보'])

# %%
badcar['weekday'] = badcar['단속일시정보'].dt.strftime('%A')

# %%
badcar.insert(badcar.columns.get_loc('단속일시정보') + 1, '요일', badcar.pop('weekday'))
# 'horsepower' 옆에 'category' 칼럼을 삽입

# %%
badcar
# Out:
#         집계년도  시군명   시군코드      관리기관명              단속일시정보         요일  \
# 0       2022  고양시  41280   고양시 덕양구청 2022-02-23 15:15:00  Wednesday
# 1       2022  고양시  41280   고양시 덕양구청 2022-02-18 15:25:00     Friday
# 2       2022  고양시  41280   고양시 덕양구청 2022-02-18 15:27:00     Friday
# 3       2022  고양시  41280   고양시 덕양구청 2022-02-23 15:12:00  Wednesday
# 4       2022  고양시  41280   고양시 덕양구청 2022-02-23 15:14:00  Wednesday
# ...      ...  ...    ...        ...                 ...        ...
# 234744  2022  고양시  41280  고양시 일산서구청 2022-12-31 17:19:00   Saturday
# 234745  2022  고양시  41280  고양시 일산서구청 2022-12-31 17:23:00   Saturday
# 234746  2022  고양시  41280  고양시 일산서구청 2022-12-31 17:39:00   Saturday
# 234747  2022  고양시  41280  고양시 일산서구청 2022-12-31 17:44:00   Saturday
# 234748  2022  고양시  41280  고양시 일산서구청 2022-12-31 23:06:00   Saturday
#
#                          단속장소     단속방법     데이터기준일자
# 0                         향동로      PDA  2024-06-04
# 1                         향동로      PDA  2024-06-04
# 2                         향동로      PDA  2024-06-04
# 3                         향동로      PDA  2024-06-04
# 4                         향동로      PDA  2024-06-04
# ...                       ...      ...         ...
# 234744  SP-7518 우리은행 일산중앙지점 앞  고정형CCTV  2024-06-04
# 234745           2033번지 소화전주변    시민신고웹  2024-06-04
# 234746    P-7527 주엽119안전센터 후문  고정형CCTV  2024-06-04
# 234747    P-7527 주엽119안전센터 후문  고정형CCTV  2024-06-04
# 234748           1876번지 모퉁이주변    시민신고웹  2024-06-04
#
# [234749 rows x 9 columns]

# %%
cartime = pd.DataFrame({'datetime':pd.to_datetime(timevalue)})
cartime
# Out:
#                   datetime
# 0      2022-02-23 15:15:00
# 1      2022-02-18 15:25:00
# 2      2022-02-18 15:27:00
# 3      2022-02-23 15:12:00
# 4      2022-02-23 15:14:00
# ...                    ...
# 234744 2022-12-31 17:19:00
# 234745 2022-12-31 17:23:00
# 234746 2022-12-31 17:39:00
# 234747 2022-12-31 17:44:00
# 234748 2022-12-31 23:06:00
#
# [234749 rows x 1 columns]

# %%
def categorize_time(time):
    hour = time.hour
    if 0 <= hour < 6:
        return '새벽'
    elif 6 <= hour < 12:
        return '오전'
    elif 12 <= hour < 18:
        return '오후'
    else:
        return '저녁'

# %%
badcar.insert(badcar.columns.get_loc('요일') + 1,'datetime')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 badcar.insert(badcar.columns.get_loc('요일') + 1,'datetime')
#
# TypeError: DataFrame.insert() missing 1 required positional argument: 'value'
