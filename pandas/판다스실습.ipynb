# %% [markdown]
# # 한국교통안전공단_용도별 차종별 연료별 연간 자동차주행거리_20191231

# %%
import pandas as pd

# %%
car = pd.read_csv('C:/ex/data/한국교통안전공단_용도별 차종별 연료별 연간 자동차주행거리_20191231.csv',encoding='cp949')
car
# Out:
#      용도별  차종별 사용연료별         전국        서울       부산       대구       인천       광주  \
# 0     전체  승용차   휘발유  116867557  15251671  6808340  5763724  8621468  3121261
# 1     전체  승용차    경유   86830023   9922186  4692249  4108136  7558018  2423047
# 2     전체  승용차   LPG   30751266   4067947  2320609  1767321  2645804  1294888
# 3     전체  승용차  기타연료    8246608   1363397   450594   432720   584504   228486
# 4     전체  승합차   휘발유      37818      7053     2233     1317     2851      928
# 5     전체  승합차    경유   14122146   1576846   676280   436159   812926   271337
# 6     전체  승합차   LPG    1003660    189346    82795    40722    59216    24084
# 7     전체  승합차  기타연료    2740748    592766   347291   160796   227796   103543
# 8     전체  화물차   휘발유     113668     16037     4944     4181     5549     1417
# 9     전체  화물차    경유   61498762   6047503  3812140  3032051  3496730  1755778
# 10    전체  화물차   LPG    1727224    454832    74591    71424   124370    40273
# ...

# %% [markdown]
# 단위: 1000km

# %% [markdown]
# li = c

# %%
a = car.사용연료별
b = a[:4].tolist()
b
# Out:
# ['휘발유', '경유', 'LPG', '기타연료']

# %%
li = car.columns.tolist()
col = li[3:]
col
a = car.사용연료별
b = a[:4].tolist()
b
# Out:
# ['전국',
#  '서울',
#  '부산',
#  '대구',
#  '인천',
#  '광주',
#  '대전',
#  '울산',
#  '세종',
#  '경기',
#  '강원',
#  '충북',
#  '충남',
#  '전북',
#  '전남',
#  '경북',
#  '경남',
#  '제주']

# %%
car.서울.iloc[[i for i in range(0,48) if i%4==0]]
# Out:
# 0     15251671
# 4         7053
# 8        16037
# 12         101
# 16    14769546
# 20        6462
# 24       15953
# 28         101
# 32      482125
# 36         592
# 40          84
# 44           0
# Name: 서울, dtype: int64

# %%
car.서울.iloc[[i for i in range(0,48) if i%4==0]]

# %%
car.head(4)
# Out:
#   용도별  차종별 사용연료별         전국        서울       부산       대구       인천       광주  \
# 0  전체  승용차   휘발유  116867557  15251671  6808340  5763724  8621468  3121261
# 1  전체  승용차    경유   86830023   9922186  4692249  4108136  7558018  2423047
# 2  전체  승용차   LPG   30751266   4067947  2320609  1767321  2645804  1294888
# 3  전체  승용차  기타연료    8246608   1363397   450594   432720   584504   228486
#
#         대전  ...      세종        경기       강원       충북       충남       전북  \
# 0  3329225  ...  933502  29605058  3563630  3947391  5398890  4102110
# 1  2320477  ...  683026  21625490  2880620  3041369  4146530  3488052
# 2  1016722  ...  171445   5676893   877064  1040787  1240655  1363881
# 3   201319  ...   89154   2136704   241932   235605   308074   260291
#
#         전남       경북       경남       제주
# 0  4794664  6800914  8990178  2922840
# 1  4294207  4732506  6170049  2738857
# 2  1589740  1707179  1969941  1461780
# 3   291003   373488   507699   395216
#
# [4 rows x 21 columns]

# %%
ccl = col
rrow =

# %% [markdown]
# ## 어떤 차종을 가장 많이 이용하는가

# %%
car['차종별']=='승용차'
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16     True
# 17     True
# 18     True
# 19     True
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32     True
# 33     True
# 34     True
# 35     True
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# Name: 차종별, dtype: bool

# %%
# 승용차인 경우의 개수
li = list(car['차종별']=='승용차')
li
li.count(True)
# Out:
# 12

# %%
values = car['차종별'].unique()
print('values:',values)
# Out:
# values: ['승용차' '승합차' '화물차' '특수차']

# %%
li1 = list(car['차종별']=='승용차')
print(li1.count(True))
li2 = list(car['차종별']=='승합차')
print(li2.count(True))
li3 = list(car['차종별']=='화물차')
print(li3.count(True))
li4 = list(car['차종별']=='특수차')
print(li4.count(True))
# Out:
# 12
# 12
# 12
# 12

# %% [markdown]
# ### 어떤 차종을 가장 많이 이용하는가
# #### => 각 차종을 이용하는 수가 동일하다

# %%
car.describe()
# Out:
#                  전국            서울            부산            대구            인천  \
# count  4.800000e+01  4.800000e+01  4.800000e+01  4.800000e+01  4.800000e+01
# mean   1.373141e+07  1.671445e+06  8.426946e+05  6.653506e+05  1.021559e+06
# std    2.873570e+07  3.562926e+06  1.657475e+06  1.444163e+06  2.014962e+06
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    3.368675e+04  6.017750e+03  1.191000e+03  1.500000e+02  2.776750e+03
# 50%    1.087751e+06  2.274160e+05  7.119450e+04  5.098400e+04  8.464900e+04
# 75%    8.365860e+06  1.182296e+06  7.352188e+05  4.257450e+05  8.251308e+05
# max    1.168676e+08  1.525167e+07  6.808340e+06  5.763724e+06  8.621468e+06
#
#                  광주            대전            울산             세종            경기  \
# count  4.800000e+01  4.800000e+01  4.800000e+01      48.000000  4.800000e+01
# mean   3.907142e+05  3.808126e+05  3.076989e+05   95139.687500  3.370221e+06
# ...

# %% [markdown]
# ## 각 지역별로 어떤 연료로 가장 많이 달리는가
# ### 서울

# %%
# for i in range(0,48):
#     if i%4==0:
        # print(i)
seoul_h = pd.DataFrame(car.iloc[[i for i in range(0,48) if i%4==0 ]])
seoul_h
# Out:
#      용도별  차종별 사용연료별         전국        서울       부산       대구       인천       광주  \
# 0     전체  승용차   휘발유  116867557  15251671  6808340  5763724  8621468  3121261
# 4     전체  승합차   휘발유      37818      7053     2233     1317     2851      928
# 8     전체  화물차   휘발유     113668     16037     4944     4181     5549     1417
# 12    전체  특수차   휘발유        270       101        5        0       27        0
# 16  비사업형  승용차   휘발유  110659186  14769546  6503344  5715626  6374479  3084441
# 20  비사업형  승합차   휘발유      36558      6462     2195     1242     2839      928
# 24  비사업형  화물차   휘발유     113319     15953     4944     4181     5549     1417
# 28  비사업형  특수차   휘발유        270       101        5        0       27        0
# 32   사업형  승용차   휘발유    6208371    482125   304996    48098  2246989    36820
# 36   사업형  승합차   휘발유       1260       592       37       76       12        0
# 40   사업형  화물차   휘발유        349        84        0        0        0        0
# ...

# %%
seoul_k = pd.DataFrame(car.iloc[[i for i in range(0,48) if i%4==1 ]]['서울'])
seoul_k
# Out:
#          서울
# 1   9922186
# 5   1576846
# 9   6047503
# 13   179291
# 17  9560501
# 21  1121929
# 25  3862306
# 29    32911
# 33   361685
# 37   454917
# 41  2185197
# 45   146381

# %%
seoul_l = pd.DataFrame(car.iloc[[i for i in range(0,48) if i%4==2 ]]['서울'])
seoul_l
# Out:
#          서울
# 2   4067947
# 6    189346
# 10   454832
# 14     2005
# 18  1757408
# 22   184661
# 26   215860
# 30       55
# 34  2310539
# 38     4685
# 42   238972
# 46     1951

# %%
li = car.columns.tolist()
col = li[3:]
col
# Out:
# ['전국',
#  '서울',
#  '부산',
#  '대구',
#  '인천',
#  '광주',
#  '대전',
#  '울산',
#  '세종',
#  '경기',
#  '강원',
#  '충북',
#  '충남',
#  '전북',
#  '전남',
#  '경북',
#  '경남',
#  '제주']

# %%
a = car.사용연료별
b = a[:4].tolist()
b
# Out:
# ['휘발유', '경유', 'LPG', '기타연료']

# %%
import numpy as np

# %%
seoul_h = car.iloc[[i for i in range(0,48) if i%4==0]][col]
ss1 = seoul_h.sum()
seoul_k = car.iloc[[i for i in range(0,48) if i%4==1]][col]
ss2 = seoul_k.sum()
seoul_l = car.iloc[[i for i in range(0,48) if i%4==2]][col]
ss3 = seoul_l.sum()
seoul_g = car.iloc[[i for i in range(0,48) if i%4==3]][col]
ss4 = seoul_g.sum()

data = np.array([[ss1],[ss2],[ss3],[ss4]])
w = data.reshape(4,18)
w
# Out:
# array([[234038626,  30549725,  13631043,  11538445,  17259790,   6247212,
#           6665150,   5829022,   1868471,  59305851,   7144349,   7908510,
#          10815162,   8212918,   9597770,  13617958,  17994198,   5853052],
#        [332804736,  35451653,  20221380,  15344376,  24316779,   9110827,
#           8758822,   7238595,   2137502,  83921205,  11617125,  12933462,
#          17427544,  14181148,  17398909,  20542351,  23889791,   8313265],
#        [ 66971072,   9428261,   4956105,   3759234,   5658832,   2718598,
#           2132013,   1153204,    359754,  12899268,   1899094,   2196266,
#           2625756,   2860909,   3355788,   3663238,   4258256,   3046496],
#        [ 25293414,   4799740,   1640815,   1294773,   1799430,    677646,
#            723018,    548724,    200978,   5644286,    577756,    617095,
#            728096,    740327,    861367,   2046382,   1467538,    925440]],
#       dtype=int64)

# %%
final = pd.DataFrame(data=w,columns=[col])
new = '사용연료별'
dataa = ['휘발유', '경유', 'LPG', '기타연료']
final.insert(0,new,dataa)

final.set_index('사용연료별',inplace=True)
final
# Out:
#                 전국        서울        부산        대구        인천       광주       대전  \
# 사용연료별
# (휘발유,)   234038626  30549725  13631043  11538445  17259790  6247212  6665150
# (경유,)    332804736  35451653  20221380  15344376  24316779  9110827  8758822
# (LPG,)    66971072   9428261   4956105   3759234   5658832  2718598  2132013
# (기타연료,)   25293414   4799740   1640815   1294773   1799430   677646   723018
#
#               울산       세종        경기        강원        충북        충남        전북  \
# 사용연료별
# (휘발유,)   5829022  1868471  59305851   7144349   7908510  10815162   8212918
# (경유,)    7238595  2137502  83921205  11617125  12933462  17427544  14181148
# (LPG,)   1153204   359754  12899268   1899094   2196266   2625756   2860909
# (기타연료,)   548724   200978   5644286    577756    617095    728096    740327
#
#                전남        경북        경남       제주
# 사용연료별
# (휘발유,)    9597770  13617958  17994198  5853052
# (경유,)    17398909  20542351  23889791  8313265
# ...

# %%
final = pd.DataFrame(data=w,columns=[col])
new = '사용연료별'
dataa = ['휘발유', '경유', 'LPG', '기타연료']
final.insert(0,new,dataa)
aaa = final['사용연료별'].replace('(', '', regex=False).replace(')', '', regex=False).replace(',', '', regex=False)
aaa.set_index('사용연료별',inplace=True)
final
# Out:
#   사용연료별         전국        서울        부산        대구        인천       광주       대전  \
# 0   휘발유  234038626  30549725  13631043  11538445  17259790  6247212  6665150
# 1    경유  332804736  35451653  20221380  15344376  24316779  9110827  8758822
# 2   LPG   66971072   9428261   4956105   3759234   5658832  2718598  2132013
# 3  기타연료   25293414   4799740   1640815   1294773   1799430   677646   723018
#
#         울산       세종        경기        강원        충북        충남        전북  \
# 0  5829022  1868471  59305851   7144349   7908510  10815162   8212918
# 1  7238595  2137502  83921205  11617125  12933462  17427544  14181148
# 2  1153204   359754  12899268   1899094   2196266   2625756   2860909
# 3   548724   200978   5644286    577756    617095    728096    740327
#
#          전남        경북        경남       제주
# 0   9597770  13617958  17994198  5853052
# 1  17398909  20542351  23889791  8313265
# 2   3355788   3663238   4258256  3046496
# 3    861367   2046382   1467538   925440

# %%
sum1 = seoul_h['서울'].sum()
print(sum1)
sum2 = seoul_k['서울'].sum()
print(sum2)
sum3 = seoul_l['서울'].sum()
print(sum3)
sum4 = seoul_g['서울'].sum()
print(sum4)

di_seoul = {'휘발유':sum1,'경유':sum2,'LPG':sum3,'기타연료':sum4}

li_seoul = [di_seoul[sum1],di_seoul[sum2],di_seoul[sum1],di_seoul[sum1],]
li_seoul.sort
print(li_seoul)
# Out:
# 30549725
# 35451653
# 9428261
# 4799740
# [30549725, 35451653, 9428261, 4799740]

# %%
a = pd.DataFrame(car.서울.iloc[[i for i in range(0,48) if i%4==0]])
b = a['서울'].sum()
b

a = pd.DataFrame(car.서울.iloc[[i for i in range(0,48) if i%4==0]])
b = a['서울'].sum()
b
# summ = a['서울'].sum
# Out:
# 30549725

# %%
di_seoul = {sum1:'휘발유',sum2:'경유',sum3:'LPG',sum4:'기타연료'}
li=[]
for key in di_seoul.keys():
    li.append(key)
li = sorted(li,reverse=True)
# print(li)
li2 = [di_seoul[key] for key in li]
print(li2)



# 숫자를 순서대로 나열한다
# li_seoul = [sum1,sum2,sum3,sum4]
# li_seoul.sort
# print(li_seoul)
# Out:
# ['경유', '휘발유', 'LPG', '기타연료']

# %%
import numpy as np

# %%
# data_seoul = np.array([[1,2,3,4],['경유', '휘발유', 'LPG', '기타연료']])
# ssoul = pd.DataFrame(data=data_seoul,columns=['순위','서울'])
# # 
# ssoul

data_seoul = pd.DataFrame({'순위':[1,2,3,4]})
data_seoul['서울'] = ['경유', '휘발유', 'LPG', '기타연료']
data_seoul.set_index('순위',inplace=True)
data_seoul
# Out:
#       서울
# 순위
# 1     경유
# 2    휘발유
# 3    LPG
# 4   기타연료

# %%
sss = pd.DataFrame({})

# %%
seoul.describe()
# Out:
#                  서울
# count  1.200000e+01
# mean   2.545810e+06
# std    5.824807e+06
# min    0.000000e+00
# 25%    1.010000e+02
# 50%    6.757500e+03
# 75%    1.325590e+05
# max    1.525167e+07

# %%
for i in range(0,30):
    if i%4==0:
        print(i)
# Out:
# 0
# 4
# 8
# 12
# 16
# 20
# 24
# 28

# %%
seoul1 = pd.
