# %% [markdown]
# # 상관과 회귀

# %% [markdown]
# 상관: corelation
#
# 세로 관련
#
# 회귀

# %%
admoney = pd.read_excel('C:/Users/acy/Desktop/새 폴더/인공지능_기초수학.xlsx',sheet_name='상관_회귀')
admoney
# Out:
#                                     연도        광고비    광고비 편차    매출액     매출액 편차  \
# 0                                 2006  13.000000 -3.466667   94.0  -4.933333
# 1                                 2007   8.000000 -8.466667   70.0 -28.933333
# 2                                 2008  10.000000 -6.466667   90.0  -8.933333
# 3                                 2009  15.000000 -1.466667  100.0   1.066667
# 4                                 2010  12.000000 -4.466667   95.0  -3.933333
# 5                                 2011  15.000000 -1.466667  100.0   1.066667
# 6                                 2012  14.000000 -2.466667   85.0 -13.933333
# 7                                 2013  15.000000 -1.466667   95.0  -3.933333
# 8                                 2014  17.000000  0.533333  105.0   6.066667
# 9                                 2015  19.000000  2.533333  105.0   6.066667
# 10                                2016  20.000000  3.533333  110.0  11.066667
# ...

# %%
pearson_corr = admoney['광고비'].corr(admoney['매출액'])
# 광고비와 매출액 사이의 피어슨 상관 계수 구하기
pearson_corr
# Out:
# 0.8879209022406115

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # adv data

# %%
import pandas as pd

# %%
pd.read_csv('C:/ex/data/adv.csv',encoding='cp949')
# Out:
#     광고비  매출액
# 0    13   94
# 1     8   70
# 2    10   90
# 3    15  100
# 4    12   95
# 5    15  100
# 6    14   85
# 7    15   95
# 8    17  105
# 9    19  105
# 10   20  110
# 11   21  105
# 12   22  104
# 13   21  105
# 14   25  121

# %%
adv = pd.read_csv('C:/ex/data/adv.csv',encoding='cp949')

# %%
import numpy as np

# %%
np.corrcoef(adv.광고비,adv.매출액)
# Out:
# array([[1.       , 0.8879209],
#        [0.8879209, 1.       ]])

# %%
adv.corr()
# Out:
#           광고비       매출액
# 광고비  1.000000  0.887921
# 매출액  0.887921  1.000000

# %% [markdown]
# # quiz data

# %%
import pandas as pd

# %%
quiz = pd.read_csv('C:/ex/data/ch12_scores_reg - 복사본.csv')
quiz
# Out:
#     quiz  final_test
# 0    4.2          67
# 1    7.2          71
# 2    0.0          19
# 3    3.0          35
# 4    1.5          35
# 5    0.9          40
# 6    1.9          23
# 7    3.5          37
# 8    4.0          39
# 9    5.4          55
# 10   4.2          40
# 11   6.9          70
# 12   2.0          29
# 13   8.8          88
# 14   0.3          47
# 15   6.7          77
# 16   4.2          52
# 17   5.6          55
# 18   1.4          18
# 19   2.0          60

# %%
quiz.corr()
# Out:
#                 quiz  final_test
# quiz        1.000000    0.822402
# final_test  0.822402    1.000000

# %% [markdown]
# # 단순 회귀 모델(직선인 모델)

# %% [markdown]
# 가설: hypothesis

# %% [markdown]
# $y = ax+b$
#
# a는 회귀 계수 / y는 회귀 모델
#
# y = 베타일x+베타영

# %% [markdown]
# x1 = 퀴즈(quiz), y = 기말고사(final_test)
#
# x1 원인이 되는 변수(설명변수,독립변수), 결과가 되는 변수(y)는 반응변수(종송변수)
#
# y = ax+b

# %%
import statsmodels.formula.api as smf

# %%
quiz.quiz
# Out:
# 0     4.2
# 1     7.2
# 2     0.0
# 3     3.0
# 4     1.5
# 5     0.9
# 6     1.9
# 7     3.5
# 8     4.0
# 9     5.4
# 10    4.2
# 11    6.9
# 12    2.0
# 13    8.8
# 14    0.3
# 15    6.7
# 16    4.2
# 17    5.6
# 18    1.4
# 19    2.0
# Name: quiz, dtype: float64

# %%
quiz.final_test
# Out:
# 0     67
# 1     71
# 2     19
# 3     35
# 4     35
# 5     40
# 6     23
# 7     37
# 8     39
# 9     55
# 10    40
# 11    70
# 12    29
# 13    88
# 14    47
# 15    77
# 16    52
# 17    55
# 18    18
# 19    60
# Name: final_test, dtype: int64

# %%
# fomula = '결과~원인'

# %%
formula = 'final_test~quiz'

# %%
# 오차 = 실제값-예측값
# 오차^2의 값이 최소로 되게끔 하는 방법을 모델로 만들어서 예측

# %%
# ordinary least squares 보통의, 일상적인
# 가장 일반적으로 오차 구하는 방법

# %%
smf.ols(formula,quiz).fit()
# ols: ordinary least square 최소 제곱법

# %%
linear_model1 = smf.ols(formula,quiz).fit()

# %%
0.82202**2
# Out:
# 0.6757168804

# %%
linear_model1.summary()
# R-squared:	0.676
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             final_test   R-squared:                       0.676
# Model:                            OLS   Adj. R-squared:                  0.658
# Method:                 Least Squares   F-statistic:                     37.61
# Date:                Thu, 08 Aug 2024   Prob (F-statistic):           8.59e-06
# Time:                        15:27:19   Log-Likelihood:                -76.325
# No. Observations:                  20   AIC:                             156.7
# Df Residuals:                      18   BIC:                             158.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     23.6995      4.714      5.028      0.000      13.796      33.603
# ...
