# %% [markdown]
# 수학에서 함수(function)이란 변수 하나와 다른 변수 간 관계를 정의하는 표현 또는 규칙

# %% [markdown]
# # 기초함수
#
# ## 함수

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 함수와 방정식

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol

# %%
x = Symbol('x')

# %%
x
# Out:
# x

# %%
eq

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
연습문제 정답: 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 데이터가 어떻게 분포되어 있는가
#
# 분산을 통해 상관 관계 파악
#
# 평균, 분산을 구해야 한다

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
