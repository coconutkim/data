# %% [markdown]
# ## 통계학 statistics
#
# 통계학은 관찰 및 조사로 얻을 수 있는 데이터로부터, 응용 수학의 기법을 이용해 수치상의 성질, 규칙성 또는 불규칙성을 찾아낸다. 통계적 기법은, 실험 계획, 데이터의 요약이나 해석을 실시하는데 있어서의 근거를 제공하는 학문이며, 폭넓은 분야에서 응용되어 실생활에 적용되고 있다.

# %% [markdown]
# ai학과 = 컴퓨터학과 + 통계학과

# %% [markdown]
# 기술 = describe, data 서술 // 루트 분산 = 표준 편차
#
# *분산이 상당히 중요한 요소다
#
# *평균: 데이터를 설명하는 대표값
#
# 추론(추정 estimate)
#
# --> 모집단 population에서 샘플을 추출하여 예측한다

# %%
import random
import numpy as np

# %%
random.random()
# Out:
# 0.04041006662305091

# %%
random.random()
# Out:
# 0.35650772586820345

# %%
np.random.rand() #random values
# Out:
# 0.0446995059098354

# %%
np.random.randn() #standard normal distribution
# Out:
# 0.06232383131497655

# %%
np.random.randn()
# Out:
# 1.3715700081832476

# %%
np.random.randn()
# Out:
# 0.9944089539628089

# %%
[np.random.randn() for i in range(1000)]
# Out:
# [-0.19843883899790274,
#  1.2285574318120842,
#  0.06365291646518975,
#  -0.817270083671935,
#  -0.6118200509289901,
#  0.9137579135634146,
#  -2.0969425487490425,
#  -0.4721779964496633,
#  -1.1084282866217916,
#  -0.015874764777109262,
#  0.39443381515033815,
#  -0.9182677401204712,
#  -0.3958631068178393,
#  0.5374760274569745,
#  -0.1460087970541496,
#  -1.0441777822491163,
#  0.48263012188345694,
#  0.3824762607224854,
#  0.11072074545121327,
#  -0.572656096536888,
#  0.2460745419845545,
#  -0.5416421610290904,
#  -2.635788751182371,
#  -1.2291447444134478,
#  -0.621501784762842,
#  0.6828136932281543,
#  -0.5263114835279326,
#  -1.7877303653036387,
#  1.497351519638993,
#  -1.5212836488050219,
#  -0.899681257374289,
#  -1.0692279870876817,
#  0.265555113612237,
#  -0.7879334863279122,
#  0.8931738199223566,
#  0.041227404141320305,
#  0.5240309841312482,
#  -0.24066860854419556,
#  -0.6557963926340231,
#  0.5188246550835017,
#  0.00688746652152564,
#  1.691416270030447,
# ...

# %%
np.mean([np.random.randn() for i in range(1000)]) #mean 평균
# Out:
# 0.0235138727136849

# %%
np.mean([np.random.randn() for i in range(10000)])
# Out:
# 0.006924012656725

# %%
np.mean([np.random.randn() for i in range(100000)])
# Out:
# 0.0019424492895811988

# %%
np.mean([np.random.randn() for i in range(1000000)])
# Out:
# 0.00011441648190316615

# %%
np.mean([np.random.randn() for i in range(10000000)])

# %%
np.var([np.random.randn() for i in range(100000)]) #variable 표본 분산
# Out:
# 0.9937343579532084

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
np.random.randn(3)
# Out:
# array([ 0.49076749, -0.41827778, -0.0856487 ])

# %%
np.random.randn(2,3)
# Out:
# array([[-0.39861545,  0.36283812, -1.08441914],
#        [-0.76498543,  1.86654374,  0.13140423]])

# %%
np.random.randn(3,3,3)
# Out:
# array([[[ 0.88347635,  0.48587891, -0.33040322],
#         [ 1.16524823,  1.05222463,  1.0510469 ],
#         [-1.95815752, -1.09893625, -0.17705758]],
#
#        [[-1.84617936,  1.53343348,  0.59329112],
#         [ 1.2190429 , -0.83028799, -0.49405312],
#         [-2.11061479, -2.23493905,  0.08946816]],
#
#        [[ 0.34119348,  0.63697893,  0.53096775],
#         [ 0.46935226, -0.40832653, -1.05537344],
#         [-0.95008899,  1.80717389,  0.80775967]]])

# %%
# %time #코드의 실행 시간으 측정하여 출력한다
[np.arange (1000000)*3 for i in range(1000)] 
#연속적인 정수를 생성하는 배열을 만든다
#*3을 통해 모든 요소가 3배 증가한 새로운 배열을 생성한다

#즉 100만 개의 요소를 가진 배열을 1000번 생성하고, 각 배열의 모든 요소를 3배 곱하는 작업
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# [array([      0,       3,       6, ..., 2999991, 2999994, 2999997]),
#  array([      0,       3,       6, ..., 2999991, 2999994, 2999997]),
#  array([      0,       3,       6, ..., 2999991, 2999994, 2999997]),
#  array([      0,       3,       6, ..., 2999991, 2999994, 2999997]),
#  array([      0,       3,       6, ..., 2999991, 2999994, 2999997]),
#  array([      0,       3,       6, ..., 2999991, 2999994, 2999997]),
#  array([      0,       3,       6, ..., 2999991, 2999994, 2999997]),
#  array([      0,       3,       6, ..., 2999991, 2999994, 2999997]),
#  array([      0,       3,       6, ..., 2999991, 2999994, 2999997]),
#  array([      0,       3,       6, ..., 2999991, 2999994, 2999997]),
#  array([      0,       3,       6, ..., 2999991, 2999994, 2999997]),
#  array([      0,       3,       6, ..., 2999991, 2999994, 2999997]),
#  array([      0,       3,       6, ..., 2999991, 2999994, 2999997]),
# ...

# %% [markdown]
# ### 그럼 이것을 무엇에 활용하는가?
#
# 데이터 전처리: 대규모 CSV 파일을 읽어와 여러 가지 전처리 작업을 해야 할 때, 어떤 전처리 방법이 가장 빠른지 비교할 수 있습니다.
#
# 이미지 처리: 이미지의 필터링, 변환 작업 등을 여러 이미지에 반복적으로 수행할 때, 가장 효율적인 방법을 찾기 위해 각 방법의 실행 시간을 측정합니다.
#
# 알고리즘 설계: 정렬, 검색, 최적화 문제 등에서 다양한 알고리즘의 성능을 비교하여 가장 빠른 알고리즘을 선택하는 데 사용할 수 있습니다.

# %%
# %time for i in range(1000): list(range(10000))*2
# Out:
# CPU times: total: 34.4 s
# Wall time: 35.3 s

# %%
# %time for i in range(1000): np.arange(10000)*2
# Out:
# CPU times: total: 0 ns
# Wall time: 11 ms

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = np.array([1,2,3])

# %%
a
# Out:
# array([1, 2, 3])

# %%
np.append(a, [4,5,6])
# Out:
# array([1, 2, 3, 4, 5, 6])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a2 = np.append(a, [4,5,6])

# %%
a2
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
help(np.append)
# append(arr, values, axis=None)

#axis 축

#axis = 0 -- 행
#axis = 0 -- 열

# %%
np.append(a,[7],axis = 0)
# Out:
# array([1, 2, 3, 7])

# %%
np.append(a,[7],axis = 1)
# AxisError: axis 1 is out of bounds for array of dimension 1

# %%
np.append(a.reshape(3,-1),[[7]],axis = 0)
# Out:
# array([[1],
#        [2],
#        [3],
#        [7]])

# %%
np.append(a.reshape(3,-1),[[7],[7],[7]],axis = 1)
# Out:
# array([[1, 7],
#        [2, 7],
#        [3, 7]])

# %%
a
# Out:
# array([1, 2, 3])

# %%
a_re = a.reshape(3,-1)

# %%
a_re
# Out:
# array([[1],
#        [2],
#        [3]])

# %%
a_re.ndim
# Out:
# 2

# %%
np.append(a_re,[[7],
                [8],
                [9]],axis = 0)
# Out:
# array([[1],
#        [2],
#        [3],
#        [7],
#        [8],
#        [9]])

# %%
np.append(a_re,[[7],
                [8],
                [9]],axis = 1)
# Out:
# array([[1, 7],
#        [2, 8],
#        [3, 9]])
