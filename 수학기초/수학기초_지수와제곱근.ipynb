# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np  #뉴메릭 파이썬

# %%
np.sqrt(4)
# Out:
# 2.0

# %%
10**0
# Out:
# 1

# %%
10**1
# Out:
# 10

# %%
10**(-1)
# Out:
# 0.1

# %%
#지수 법칙

# %%
result1 = 2**3*2**4
result2 = 2**7
print(result1, result2)
# Out:
# 128 128

# %%
result1 = 2**3/2**4
result2 = 2**(-1)
print(result1, result2)
# Out:
# 0.5 0.5

# %%
result1 = (2**3)**4
result2 = 2**12
print(result1, result2)
# Out:
# 4096 4096

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
np.sqrt(2)
# Out:
# 1.4142135623730951

# %%
np.sqrt(4)
# Out:
# 2.0

# %%
# help(np.sqrt)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# sympy: symbolic mathemaetics

# %%
import sympy

# %%
help(sympy)

# %%
from sympy import expand, factor, Symbol

# %%
x = Symbol('x')

# %%
type(x)
# Out:
# sympy.core.symbol.Symbol

# %%
x
# Out:
# x

# %%
expand((x+1)*(x+5))
# Out:
# x**2 + 6*x + 5

# %%
factor(x**2+6*x+5)
# Out:
# (x + 1)*(x + 5)

# %% [markdown]
# 1) $x^3y-xy^3$

# %%
y = Symbol('y')

# %%
y
# Out:
# y

# %%
factor(x**3*y-x*y**3)
# Out:
# x*y*(x - y)*(x + y)

# %%
factor(x**2+3*x+2)
# Out:
# (x + 1)*(x + 2)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $A = x^2+2x+1$
#
# $B = 2x^2+4x-5$

# %%
factor(x**2+2*x+1)
# Out:
# (x + 1)**2

# %%
factor(2*x**2+4*x-5)
# Out:
# 2*x**2 + 4*x - 5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $x^2+2xy+y^2-2x-3y-3$
