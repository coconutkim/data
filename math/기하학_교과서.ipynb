# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $5^2 = 3^2+4^2$

# %% [markdown]
# 활성화 함수: 계단, velu, 하이퍼볼릭 탄젠트
#
# -----------------------------------------
#
# 하이퍼볼릭 탄젠트란?
#
# -Hyperbolic Tangent, 혹은 Tanh
#
# -실수 값을 (-1, 1) 범위로 압축하는 활성화 함수
#
# -원점을 중심으로 하여 값이 양의 무한대로 갈수록 1에 수렴하고, 값이 음의 무한대로 갈수록 -1에 수렴한다
#
# -형태가 S자를 닮았기 때문에 'Sigmoid 함수'의 일종으로 간주되며, 이런 특징 덕분에 비선형성을 모델에 부여할 수 있다

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## "오차역전파"
#
#
# 구조가 복잡한 모델: 분류하기에 까다롭다 >> 머신러닝 활용
#
#
#
#
# 예를 들어 사과의 무게, 둘레 등에 따라 분류한다
#
# --> 모델을 만들어낼 데이터 = 훈련 데이터
#
# 이때 정확한 측정 지표, 평가 지표가 있어야 한다
#
# 오차를 줄여나가는게 핵심
#
# 오차를 줄이는데 거꾸로 간다

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 로지스틱 logistic 함수
#
# 로지스틱 함수: 개체군의 성장 등을 나타내는 함수이다. 로지스트형 개체군 성장 모델(logistic model of population growth)는 개체군 생태학에서 개체군의 증가율을 설명하는 모델로 1838년 Verhulst가 고안해 냈다.
#
# 시그모이드의 한 종류
#
# 시그모이드 함수: 실수 전체를 정의역으로 가지며, 반환값은 단조증가하는 것이 일반적이지만 단조감소할 수도 있다. 시그모이드 함수의 반환값(y축)은 흔히 0에서 1까지의 범위를 가진다. 또는 -1부터 1까지의 범위를 가지기도 한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 추론하기 위해 확률을 집어넣는다
#
# 확률은 0과 1 사이

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $2^3 = 8$
#
# 2의 3승은 8이다

# %% [markdown]
# ![image.png](data:image/png;base64,...)
